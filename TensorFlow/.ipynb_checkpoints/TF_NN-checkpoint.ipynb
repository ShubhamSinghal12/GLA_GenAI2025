# %% [markdown]
# # TensorFlow NN
# - Sequential
# - Functional
# - Flow: Make the model, Complie, Fit, Predict, Evaluate, Visualization of loss and acc

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.datasets import make_circles
import matplotlib.pyplot as plt

# %%
X,y = make_circles(1000,noise = 0.03)

# %%
plt.scatter(X[:,0],X[:,1],c=y)
plt.show()

# %%
import numpy as np

def plot_decision_boundary(model, X, y):
  """
  Plots the decision boundary created by a model predicting on X.
  This function has been adapted from two phenomenal resources:
   1. CS231n - https://cs231n.github.io/neural-networks-case-study/
   2. Made with ML basics - https://github.com/GokuMohandas/MadeWithML/blob/main/notebooks/08_Neural_Networks.ipynb
  """
  # Define the axis boundaries of the plot and create a meshgrid
  x_min, x_max = X[:, 0].min() - 0.1, X[:, 0].max() + 0.1
  y_min, y_max = X[:, 1].min() - 0.1, X[:, 1].max() + 0.1
  xx, yy = np.meshgrid(np.linspace(x_min, x_max, 100),
                       np.linspace(y_min, y_max, 100))

  # Create X values (we're going to predict on all of these)
  x_in = np.c_[xx.ravel(), yy.ravel()] # stack 2D arrays together: https://numpy.org/devdocs/reference/generated/numpy.c_.html

  # Make predictions using the trained model
  y_pred = model.predict(x_in)

  # Check for multi-class
  if model.output_shape[-1] > 1: # checks the final dimension of the model's output shape, if this is > (greater than) 1, it's multi-class
    print("doing multiclass classification...")
    # We have to reshape our predictions to get them ready for plotting
    y_pred = np.argmax(y_pred, axis=1).reshape(xx.shape)
  else:
    print("doing binary classifcation...")
    y_pred = np.round(np.max(y_pred, axis=1)).reshape(xx.shape)

  # Plot decision boundary
  plt.contourf(xx, yy, y_pred, cmap=plt.cm.RdYlBu, alpha=0.7)
  plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.RdYlBu)
  plt.xlim(xx.min(), xx.max())
  plt.ylim(yy.min(), yy.max())

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train,y_test = train_test_split(X,y,train_size=0.8)
print(x_train.shape,x_test.shape)
# Out:
# (800, 2) (200, 2)

# %%
# model = keras.Sequential([
#     keras.layers.Input(shape=(2,)),
#     layers.Dense(16,activation='relu'),
#     layers.Dense(8,activation='relu'),
#     layers.Dense(4,activation='relu'),
#     layers.Dense(2,activation='softmax')
# ])
# print(model.summary())


model = keras.Sequential()
model.add(keras.Input(shape=(2,)))
model.add(layers.Dense(10,activation='relu'))
model.add(layers.Dense(20,activation='relu'))
model.add(layers.Dense(10,activation='relu'))
model.add(layers.Dense(1,activation='sigmoid'))
print(model.summary())

model.compile(
    loss = keras.losses.BinaryCrossentropy,
    optimizer = keras.optimizers.Adam(learning_rate = 0.001),
    metrics = ["accuracy"]
)
history = model.fit(x_train,y_train,batch_size=80,epochs=100,validation_data=(x_test,y_test))
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_24 (Dense)                     │ (None, 10)                  │              30 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_25 (Dense)                     │ (None, 20)                  │             220 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_26 (Dense)                     │ (None, 10)                  │             210 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_27 (Dense)                     │ (None, 1)                   │              11 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 471 (1.84 KB)
#  Trainable params: 471 (1.84 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.5060 - loss: 0.6914 - val_accuracy: 0.4800 - val_loss: 0.6949
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5209 - loss: 0.6890 - val_accuracy: 0.4600 - val_loss: 0.6955
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5168 - loss: 0.6883 - val_accuracy: 0.4600 - val_loss: 0.6961
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5413 - loss: 0.6866 - val_accuracy: 0.4600 - val_loss: 0.6971
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5258 - loss: 0.6871 - val_accuracy: 0.4650 - val_loss: 0.6970
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5339 - loss: 0.6846 - val_accuracy: 0.4700 - val_loss: 0.6969
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5101 - loss: 0.6872 - val_accuracy: 0.4700 - val_loss: 0.6966
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5018 - loss: 0.6885 - val_accuracy: 0.4650 - val_loss: 0.6965
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5258 - loss: 0.6826 - val_accuracy: 0.4600 - val_loss: 0.6960
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4995 - loss: 0.6863 - val_accuracy: 0.4750 - val_loss: 0.6949
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5473 - loss: 0.6804 - val_accuracy: 0.4800 - val_loss: 0.6948
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5264 - loss: 0.6823 - val_accuracy: 0.4750 - val_loss: 0.6940
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5169 - loss: 0.6791 - val_accuracy: 0.4850 - val_loss: 0.6925
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5264 - loss: 0.6756 - val_accuracy: 0.4800 - val_loss: 0.6919
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5294 - loss: 0.6775 - val_accuracy: 0.4950 - val_loss: 0.6889
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5288 - loss: 0.6738 - val_accuracy: 0.4950 - val_loss: 0.6875
# Epoch 17/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5159 - loss: 0.6747 - val_accuracy: 0.4950 - val_loss: 0.6842
# Epoch 18/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5353 - loss: 0.6738 - val_accuracy: 0.4850 - val_loss: 0.6819
# Epoch 19/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5426 - loss: 0.6661 - val_accuracy: 0.5000 - val_loss: 0.6797
# Epoch 20/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5290 - loss: 0.6637 - val_accuracy: 0.5050 - val_loss: 0.6742
# Epoch 21/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5651 - loss: 0.6578 - val_accuracy: 0.5800 - val_loss: 0.6669
# Epoch 22/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5823 - loss: 0.6563 - val_accuracy: 0.6050 - val_loss: 0.6607
# Epoch 23/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5753 - loss: 0.6553 - val_accuracy: 0.6150 - val_loss: 0.6533
# Epoch 24/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5934 - loss: 0.6473 - val_accuracy: 0.6150 - val_loss: 0.6489
# Epoch 25/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6174 - loss: 0.6385 - val_accuracy: 0.6450 - val_loss: 0.6392
# Epoch 26/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6341 - loss: 0.6311 - val_accuracy: 0.6250 - val_loss: 0.6353
# Epoch 27/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6366 - loss: 0.6214 - val_accuracy: 0.6700 - val_loss: 0.6239
# Epoch 28/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6586 - loss: 0.6125 - val_accuracy: 0.6750 - val_loss: 0.6145
# Epoch 29/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7066 - loss: 0.6080 - val_accuracy: 0.7350 - val_loss: 0.6031
# Epoch 30/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7108 - loss: 0.5938 - val_accuracy: 0.7500 - val_loss: 0.5927
# Epoch 31/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7662 - loss: 0.5821 - val_accuracy: 0.8400 - val_loss: 0.5770
# Epoch 32/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7840 - loss: 0.5785 - val_accuracy: 0.7800 - val_loss: 0.5688
# Epoch 33/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7993 - loss: 0.5564 - val_accuracy: 0.8400 - val_loss: 0.5495
# Epoch 34/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8411 - loss: 0.5492 - val_accuracy: 0.8650 - val_loss: 0.5335
# Epoch 35/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8578 - loss: 0.5290 - val_accuracy: 0.8500 - val_loss: 0.5191
# Epoch 36/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8571 - loss: 0.5067 - val_accuracy: 0.8850 - val_loss: 0.4963
# Epoch 37/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8918 - loss: 0.4856 - val_accuracy: 0.8900 - val_loss: 0.4749
# Epoch 38/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8824 - loss: 0.4801 - val_accuracy: 0.8950 - val_loss: 0.4570
# Epoch 39/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8815 - loss: 0.4530 - val_accuracy: 0.9050 - val_loss: 0.4289
# Epoch 40/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8965 - loss: 0.4329 - val_accuracy: 0.9200 - val_loss: 0.4091
# Epoch 41/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9018 - loss: 0.4109 - val_accuracy: 0.9450 - val_loss: 0.3819
# Epoch 42/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9100 - loss: 0.3881 - val_accuracy: 0.9300 - val_loss: 0.3648
# Epoch 43/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9112 - loss: 0.3630 - val_accuracy: 0.9500 - val_loss: 0.3357
# Epoch 44/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9363 - loss: 0.3318 - val_accuracy: 0.9600 - val_loss: 0.3135
# Epoch 45/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9492 - loss: 0.3197 - val_accuracy: 0.9700 - val_loss: 0.2920
# Epoch 46/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9488 - loss: 0.2927 - val_accuracy: 0.9750 - val_loss: 0.2718
# Epoch 47/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9793 - loss: 0.2727 - val_accuracy: 0.9800 - val_loss: 0.2519
# Epoch 48/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9785 - loss: 0.2647 - val_accuracy: 0.9850 - val_loss: 0.2272
# Epoch 49/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9893 - loss: 0.2447 - val_accuracy: 0.9850 - val_loss: 0.2095
# Epoch 50/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9933 - loss: 0.2213 - val_accuracy: 0.9950 - val_loss: 0.1961
# Epoch 51/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9961 - loss: 0.2091 - val_accuracy: 0.9950 - val_loss: 0.1785
# Epoch 52/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9912 - loss: 0.1906 - val_accuracy: 0.9950 - val_loss: 0.1639
# Epoch 53/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9954 - loss: 0.1803 - val_accuracy: 0.9950 - val_loss: 0.1509
# Epoch 54/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9970 - loss: 0.1604 - val_accuracy: 0.9950 - val_loss: 0.1397
# Epoch 55/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9966 - loss: 0.1468 - val_accuracy: 1.0000 - val_loss: 0.1251
# Epoch 56/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9996 - loss: 0.1399 - val_accuracy: 1.0000 - val_loss: 0.1165
# Epoch 57/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.1272 - val_accuracy: 1.0000 - val_loss: 0.1070
# Epoch 58/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9993 - loss: 0.1163 - val_accuracy: 1.0000 - val_loss: 0.1003
# Epoch 59/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9983 - loss: 0.1129 - val_accuracy: 1.0000 - val_loss: 0.0908
# Epoch 60/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.1020 - val_accuracy: 1.0000 - val_loss: 0.0858
# Epoch 61/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0958 - val_accuracy: 1.0000 - val_loss: 0.0771
# Epoch 62/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0888 - val_accuracy: 1.0000 - val_loss: 0.0758
# Epoch 63/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0836 - val_accuracy: 1.0000 - val_loss: 0.0672
# Epoch 64/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0790 - val_accuracy: 1.0000 - val_loss: 0.0640
# Epoch 65/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0707 - val_accuracy: 1.0000 - val_loss: 0.0577
# Epoch 66/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0664 - val_accuracy: 1.0000 - val_loss: 0.0579
# Epoch 67/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0663 - val_accuracy: 1.0000 - val_loss: 0.0508
# Epoch 68/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0611 - val_accuracy: 1.0000 - val_loss: 0.0474
# Epoch 69/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0578 - val_accuracy: 1.0000 - val_loss: 0.0457
# Epoch 70/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0505 - val_accuracy: 1.0000 - val_loss: 0.0414
# Epoch 71/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0483 - val_accuracy: 1.0000 - val_loss: 0.0395
# Epoch 72/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0429 - val_accuracy: 1.0000 - val_loss: 0.0373
# Epoch 73/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0396 - val_accuracy: 1.0000 - val_loss: 0.0357
# Epoch 74/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0407 - val_accuracy: 1.0000 - val_loss: 0.0337
# Epoch 75/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0363 - val_accuracy: 1.0000 - val_loss: 0.0321
# Epoch 76/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0374 - val_accuracy: 1.0000 - val_loss: 0.0294
# Epoch 77/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0361 - val_accuracy: 1.0000 - val_loss: 0.0299
# Epoch 78/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0330 - val_accuracy: 1.0000 - val_loss: 0.0266
# Epoch 79/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0305 - val_accuracy: 1.0000 - val_loss: 0.0263
# Epoch 80/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0305 - val_accuracy: 1.0000 - val_loss: 0.0249
# Epoch 81/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0289 - val_accuracy: 1.0000 - val_loss: 0.0234
# Epoch 82/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0255 - val_accuracy: 1.0000 - val_loss: 0.0222
# Epoch 83/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0247 - val_accuracy: 1.0000 - val_loss: 0.0214
# Epoch 84/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0238 - val_accuracy: 1.0000 - val_loss: 0.0199
# Epoch 85/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0221 - val_accuracy: 1.0000 - val_loss: 0.0187
# Epoch 86/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0200 - val_accuracy: 1.0000 - val_loss: 0.0179
# Epoch 87/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0214 - val_accuracy: 1.0000 - val_loss: 0.0172
# Epoch 88/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0180 - val_accuracy: 1.0000 - val_loss: 0.0164
# Epoch 89/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0171 - val_accuracy: 1.0000 - val_loss: 0.0158
# Epoch 90/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0165 - val_accuracy: 1.0000 - val_loss: 0.0156
# Epoch 91/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0166 - val_accuracy: 1.0000 - val_loss: 0.0148
# Epoch 92/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0151 - val_accuracy: 1.0000 - val_loss: 0.0147
# Epoch 93/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0157 - val_accuracy: 1.0000 - val_loss: 0.0146
# Epoch 94/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0164 - val_accuracy: 1.0000 - val_loss: 0.0136
# Epoch 95/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0142 - val_accuracy: 1.0000 - val_loss: 0.0137
# Epoch 96/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0134 - val_accuracy: 1.0000 - val_loss: 0.0131
# Epoch 97/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0143 - val_accuracy: 1.0000 - val_loss: 0.0130
# Epoch 98/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0146 - val_accuracy: 1.0000 - val_loss: 0.0130
# Epoch 99/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0128 - val_accuracy: 1.0000 - val_loss: 0.0121
# Epoch 100/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0124 - val_accuracy: 1.0000 - val_loss: 0.0122

# %%
plot_decision_boundary(model,x_train,y_train)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step
# doing binary classifcation...

# %%
history.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
plt.plot(history.history['accuracy'],label = 'accuracy')
plt.plot(history.history['loss'],label = 'loss')

plt.legend()
plt.xlabel('epochs')
plt.grid()
plt.show()

# %%
model.evaluate(x_test,y_test)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0136
# [0.012223392724990845, 1.0]

# %%
Input = keras.Input(shape=(2,))
x = layers.Dense(10,activation='relu')(Input)
x = layers.Dense(20,activation='relu')(x)
x = layers.Dense(10,activation='relu')(x)
output = layers.Dense(1,activation='sigmoid')(x)

model = keras.Model(inputs = Input, outputs = output)

print(model.summary())

model.compile(
    loss = keras.losses.BinaryCrossentropy(),
    optimizer = keras.optimizers.Adam(learning_rate = 0.001),
    metrics = ["accuracy"]
)
history = model.fit(x_train,y_train,batch_size=80,epochs=100,validation_data=(x_test,y_test))
# Out:
# Model: "functional_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_8 (InputLayer)           │ (None, 2)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_32 (Dense)                     │ (None, 10)                  │              30 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_33 (Dense)                     │ (None, 20)                  │             220 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_34 (Dense)                     │ (None, 10)                  │             210 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_35 (Dense)                     │ (None, 1)                   │              11 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 471 (1.84 KB)
#  Trainable params: 471 (1.84 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.5157 - loss: 0.6918 - val_accuracy: 0.5250 - val_loss: 0.6928
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5105 - loss: 0.6897 - val_accuracy: 0.4450 - val_loss: 0.6929
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5258 - loss: 0.6883 - val_accuracy: 0.4550 - val_loss: 0.6925
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5173 - loss: 0.6876 - val_accuracy: 0.4550 - val_loss: 0.6920
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5275 - loss: 0.6854 - val_accuracy: 0.4550 - val_loss: 0.6917
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5088 - loss: 0.6861 - val_accuracy: 0.4550 - val_loss: 0.6913
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5107 - loss: 0.6853 - val_accuracy: 0.4550 - val_loss: 0.6907
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5023 - loss: 0.6853 - val_accuracy: 0.4550 - val_loss: 0.6900
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4822 - loss: 0.6866 - val_accuracy: 0.4550 - val_loss: 0.6892
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4973 - loss: 0.6835 - val_accuracy: 0.4550 - val_loss: 0.6884
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5078 - loss: 0.6809 - val_accuracy: 0.4550 - val_loss: 0.6878
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5099 - loss: 0.6783 - val_accuracy: 0.4550 - val_loss: 0.6873
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4838 - loss: 0.6811 - val_accuracy: 0.4550 - val_loss: 0.6848
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5028 - loss: 0.6753 - val_accuracy: 0.4550 - val_loss: 0.6837
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5321 - loss: 0.6686 - val_accuracy: 0.4550 - val_loss: 0.6824
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5112 - loss: 0.6690 - val_accuracy: 0.4550 - val_loss: 0.6789
# Epoch 17/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5179 - loss: 0.6687 - val_accuracy: 0.4750 - val_loss: 0.6744
# Epoch 18/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5540 - loss: 0.6617 - val_accuracy: 0.5550 - val_loss: 0.6710
# Epoch 19/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6107 - loss: 0.6569 - val_accuracy: 0.5800 - val_loss: 0.6673
# Epoch 20/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6413 - loss: 0.6522 - val_accuracy: 0.6200 - val_loss: 0.6620
# Epoch 21/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6816 - loss: 0.6524 - val_accuracy: 0.6350 - val_loss: 0.6569
# Epoch 22/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6955 - loss: 0.6458 - val_accuracy: 0.5750 - val_loss: 0.6523
# Epoch 23/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6308 - loss: 0.6378 - val_accuracy: 0.5950 - val_loss: 0.6460
# Epoch 24/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6575 - loss: 0.6325 - val_accuracy: 0.6700 - val_loss: 0.6348
# Epoch 25/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7330 - loss: 0.6254 - val_accuracy: 0.6950 - val_loss: 0.6237
# Epoch 26/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7092 - loss: 0.6113 - val_accuracy: 0.7450 - val_loss: 0.6104
# Epoch 27/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7899 - loss: 0.5993 - val_accuracy: 0.8900 - val_loss: 0.5949
# Epoch 28/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9077 - loss: 0.5902 - val_accuracy: 0.9050 - val_loss: 0.5796
# Epoch 29/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8818 - loss: 0.5759 - val_accuracy: 0.9200 - val_loss: 0.5617
# Epoch 30/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9309 - loss: 0.5562 - val_accuracy: 0.9200 - val_loss: 0.5442
# Epoch 31/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9260 - loss: 0.5363 - val_accuracy: 0.9700 - val_loss: 0.5211
# Epoch 32/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9720 - loss: 0.5173 - val_accuracy: 0.9750 - val_loss: 0.4994
# Epoch 33/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9797 - loss: 0.5003 - val_accuracy: 0.9900 - val_loss: 0.4728
# Epoch 34/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9757 - loss: 0.4704 - val_accuracy: 0.9850 - val_loss: 0.4470
# Epoch 35/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9829 - loss: 0.4488 - val_accuracy: 0.9950 - val_loss: 0.4202
# Epoch 36/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9844 - loss: 0.4244 - val_accuracy: 0.9950 - val_loss: 0.3920
# Epoch 37/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9899 - loss: 0.3956 - val_accuracy: 0.9900 - val_loss: 0.3665
# Epoch 38/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9899 - loss: 0.3709 - val_accuracy: 1.0000 - val_loss: 0.3400
# Epoch 39/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9961 - loss: 0.3386 - val_accuracy: 0.9950 - val_loss: 0.3148
# Epoch 40/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9953 - loss: 0.3244 - val_accuracy: 1.0000 - val_loss: 0.2920
# Epoch 41/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9883 - loss: 0.2943 - val_accuracy: 1.0000 - val_loss: 0.2663
# Epoch 42/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9983 - loss: 0.2712 - val_accuracy: 1.0000 - val_loss: 0.2493
# Epoch 43/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9986 - loss: 0.2580 - val_accuracy: 1.0000 - val_loss: 0.2303
# Epoch 44/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9978 - loss: 0.2369 - val_accuracy: 1.0000 - val_loss: 0.2083
# Epoch 45/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9973 - loss: 0.2176 - val_accuracy: 1.0000 - val_loss: 0.1941
# Epoch 46/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9988 - loss: 0.1985 - val_accuracy: 1.0000 - val_loss: 0.1774
# Epoch 47/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.1837 - val_accuracy: 1.0000 - val_loss: 0.1660
# Epoch 48/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9981 - loss: 0.1662 - val_accuracy: 1.0000 - val_loss: 0.1521
# Epoch 49/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9966 - loss: 0.1612 - val_accuracy: 1.0000 - val_loss: 0.1408
# Epoch 50/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9996 - loss: 0.1493 - val_accuracy: 1.0000 - val_loss: 0.1303
# Epoch 51/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.1341 - val_accuracy: 1.0000 - val_loss: 0.1219
# Epoch 52/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9978 - loss: 0.1224 - val_accuracy: 1.0000 - val_loss: 0.1120
# Epoch 53/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9966 - loss: 0.1202 - val_accuracy: 1.0000 - val_loss: 0.1072
# Epoch 54/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.1127 - val_accuracy: 1.0000 - val_loss: 0.0978
# Epoch 55/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9998 - loss: 0.0989 - val_accuracy: 1.0000 - val_loss: 0.0933
# Epoch 56/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9993 - loss: 0.0967 - val_accuracy: 1.0000 - val_loss: 0.0859
# Epoch 57/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9996 - loss: 0.0884 - val_accuracy: 1.0000 - val_loss: 0.0808
# Epoch 58/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9983 - loss: 0.0830 - val_accuracy: 1.0000 - val_loss: 0.0770
# Epoch 59/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9986 - loss: 0.0837 - val_accuracy: 1.0000 - val_loss: 0.0715
# Epoch 60/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0763 - val_accuracy: 1.0000 - val_loss: 0.0673
# Epoch 61/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9983 - loss: 0.0716 - val_accuracy: 1.0000 - val_loss: 0.0639
# Epoch 62/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0656 - val_accuracy: 1.0000 - val_loss: 0.0595
# Epoch 63/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9983 - loss: 0.0611 - val_accuracy: 1.0000 - val_loss: 0.0578
# Epoch 64/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0593 - val_accuracy: 1.0000 - val_loss: 0.0536
# Epoch 65/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0576 - val_accuracy: 1.0000 - val_loss: 0.0512
# Epoch 66/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0547 - val_accuracy: 1.0000 - val_loss: 0.0496
# Epoch 67/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0486 - val_accuracy: 1.0000 - val_loss: 0.0463
# Epoch 68/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9995 - loss: 0.0478 - val_accuracy: 1.0000 - val_loss: 0.0443
# Epoch 69/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0420 - val_accuracy: 1.0000 - val_loss: 0.0424
# Epoch 70/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0427 - val_accuracy: 1.0000 - val_loss: 0.0402
# Epoch 71/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0414 - val_accuracy: 1.0000 - val_loss: 0.0385
# Epoch 72/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0403 - val_accuracy: 1.0000 - val_loss: 0.0379
# Epoch 73/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0390 - val_accuracy: 1.0000 - val_loss: 0.0358
# Epoch 74/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9996 - loss: 0.0365 - val_accuracy: 1.0000 - val_loss: 0.0341
# Epoch 75/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0376 - val_accuracy: 1.0000 - val_loss: 0.0343
# Epoch 76/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0327 - val_accuracy: 1.0000 - val_loss: 0.0310
# Epoch 77/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0316 - val_accuracy: 1.0000 - val_loss: 0.0309
# Epoch 78/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0301 - val_accuracy: 1.0000 - val_loss: 0.0292
# Epoch 79/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0317 - val_accuracy: 1.0000 - val_loss: 0.0277
# Epoch 80/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0287 - val_accuracy: 1.0000 - val_loss: 0.0280
# Epoch 81/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0261 - val_accuracy: 1.0000 - val_loss: 0.0262
# Epoch 82/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0273 - val_accuracy: 1.0000 - val_loss: 0.0254
# Epoch 83/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0239 - val_accuracy: 1.0000 - val_loss: 0.0240
# Epoch 84/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0224 - val_accuracy: 1.0000 - val_loss: 0.0231
# Epoch 85/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0236 - val_accuracy: 1.0000 - val_loss: 0.0234
# Epoch 86/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0212 - val_accuracy: 1.0000 - val_loss: 0.0224
# Epoch 87/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0215 - val_accuracy: 1.0000 - val_loss: 0.0215
# Epoch 88/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0223 - val_accuracy: 1.0000 - val_loss: 0.0212
# Epoch 89/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0199 - val_accuracy: 1.0000 - val_loss: 0.0206
# Epoch 90/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0174 - val_accuracy: 1.0000 - val_loss: 0.0202
# Epoch 91/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0176 - val_accuracy: 1.0000 - val_loss: 0.0198
# Epoch 92/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0196 - val_accuracy: 1.0000 - val_loss: 0.0195
# Epoch 93/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0184 - val_accuracy: 1.0000 - val_loss: 0.0191
# Epoch 94/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0169 - val_accuracy: 1.0000 - val_loss: 0.0176
# Epoch 95/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0166 - val_accuracy: 1.0000 - val_loss: 0.0179
# Epoch 96/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0154 - val_accuracy: 1.0000 - val_loss: 0.0177
# Epoch 97/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0148 - val_accuracy: 1.0000 - val_loss: 0.0170
# Epoch 98/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0159 - val_accuracy: 1.0000 - val_loss: 0.0171
# Epoch 99/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0151 - val_accuracy: 1.0000 - val_loss: 0.0165
# Epoch 100/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0148 - val_accuracy: 1.0000 - val_loss: 0.0166

# %%
model.inputs
# Out:
# [<KerasTensor shape=(None, 2), dtype=float32, sparse=False, ragged=False, name=keras_tensor_46>]

# %%
model.layers
# Out:
# [<InputLayer name=input_layer_8, built=True>,
#  <Dense name=dense_32, built=True>,
#  <Dense name=dense_33, built=True>,
#  <Dense name=dense_34, built=True>,
#  <Dense name=dense_35, built=True>]

# %%
model.layers[-1].output
# Out:
# <KerasTensor shape=(None, 1), dtype=float32, sparse=False, ragged=False, name=keras_tensor_50>

# %%
# new_model = keras.Model(inputs = model.inputs,
#                         outputs = model.get_layer('dense_6').output)
new_model = keras.Model(inputs = model.inputs,
                        outputs = [model.layers[-2].output,model.layers[-1].output])
print(new_model.summary())

features = new_model.predict(x_test)
# for feat in features:
#     print(feat.shape)
# Out:
# Model: "functional_14"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_8 (InputLayer)           │ (None, 2)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_32 (Dense)                     │ (None, 10)                  │              30 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_33 (Dense)                     │ (None, 20)                  │             220 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_34 (Dense)                     │ (None, 10)                  │             210 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_35 (Dense)                     │ (None, 1)                   │              11 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 471 (1.84 KB)
#  Trainable params: 471 (1.84 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# C:\Users\abhis\miniconda3\Lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor_46']
# Received: inputs=Tensor(shape=(32, 2))
#   warnings.warn(msg)
# C:\Users\abhis\miniconda3\Lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor_46']
# Received: inputs=Tensor(shape=(None, 2))
#   warnings.warn(msg)

# %%
features[0].shape
# Out:
# (200, 10)

# %%
features[1].shape
# Out:
# (200, 1)
